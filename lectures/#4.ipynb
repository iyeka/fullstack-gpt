# %% [markdown]
# # 4 Model IO
# ## 4.0 Modules
# 1. Model I/O (Input/Output)
#     - Prompts, Language models, Output parsers
# 2. Retrieval: 외부 데이터를 모델에 제공
#     - Document loaders, Document transformers, Text embedding, Vector store, Retriever
# 3. Chains
# 4. Agents
