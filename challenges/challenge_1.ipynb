# %% [markdown]
# # 2.0 ~ # 3.5
# - [x] Create a Github Repository
# - [x] Create a Python environment.
# - [x] Install dependencies.
# - [x] Create a Jupyter Notebook.
# - [x] Setup your OpenAI Keys.
# - Make two chains and chain them together using LCEL.
#     - [x] Make a chain that is specialized in writing Haikus about programming languages and another one that is specialized in explaining Haikus.
#     - [x] Chain the two chains together using LCEL.
#     - [x] The final chain should receive the name of a programming language and it should reply with the Haiku and its explanation.
#     - [x] Use "gpt-3.5-turbo" as the model and ChatPromptTemplate for your prompts.
# - [x] Push the code to Github

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(
    temperature=0.3,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
)

poet_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are specialized in writing Haikus. You write Haikus about programming languages."),
    ("human", "{programming_language}")
])

critic_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are specialized in explaining Haikus. You receive the Haiku and reply with the its explanation."),
    ("human", "{haiku}")
])

poet_chain = poet_prompt | chat
critic_chain = critic_prompt | chat
final_chain = {"haiku": poet_chain} | critic_chain

final_chain.invoke({"programming_language": "Ruby"})
# Out:
# Failed to post https://api.smith.langchain.com/runs in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs', '{"error":"Forbidden"}\n')
# Failed to patch https://api.smith.langchain.com/runs/9d8b7bed-7858-4033-ab9b-8564b22a3886 in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/9d8b7bed-7858-4033-ab9b-8564b22a3886', '{"detail":"Forbidden"}')
# Elegant and clean,
# Ruby shines bright with its gems,
# Code with joy and ease.This Haiku describes the beauty and simplicity of the Ruby programming language. It highlights how elegant and clean Ruby code can be, shining brightly with its gems (which are libraries or packages that extend its functionality). The last line suggests that coding in Ruby can bring joy and be done with ease, emphasizing the language's user-friendly nature.
# AIMessageChunk(content="This Haiku describes the beauty and simplicity of the Ruby programming language. It highlights how elegant and clean Ruby code can be, shining brightly with its gems (which are libraries or packages that extend its functionality). The last line suggests that coding in Ruby can bring joy and be done with ease, emphasizing the language's user-friendly nature.")
